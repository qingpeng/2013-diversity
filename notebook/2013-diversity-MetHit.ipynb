# %%
import pandas as pd
import numpy as np
import scipy
from IPython.display import HTML
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.spatial.distance import pdist, squareform
from IPython.display import Image
from pandas import *

# %%
GOS=pd.read_csv('../data/matrix.out_MetHit',delimiter=' ',header=None)

# %%
#label=pd.read_csv('../data/config-GOS.txt',delimiter='  ',header=None)
label = GOS.iloc[:,0].tolist()
len(label)
GOS=GOS.ix[:,1:39]

# %%
GOS.columns=label
GOS.index=label
GOS
GOS.to_csv("../data/dm_Methit_new.txt",sep="\t")

# %%
f_label = open('../data/MH_label.txt','r')
s = f_label.readlines()
lines = s[0].split('\r')


labels = {}
count = 1
for line in lines:
    line = line.rstrip()
    #print count
    if count%6 == 1:
        sample = line
        labels[sample]=line
    else:
        labels[sample] = labels[sample]+'>'+line
    count = count+1
#print labels

label = GOS.columns
label
L = []
for l in label:
    ll = l.split('_out')[0]
    #print ll
    L.append(labels[ll])

# %%
L
sample_md = {}
for each_L in L:
    fields = each_L.split(">")
    label = fields[0]+'_out.list.freq_table'
    disease =  fields[0].split(".")[1].split('-')[0]
    if fields[5] == 'N':
        ibd = 'N'
    else:
        ibd = disease
    sample_md[label] = {'gender':fields[2],'age':fields[3],'BMI':fields[4],'IBD':ibd}
sample_md = pd.DataFrame.from_dict(sample_md, orient='index')
sample_md
# Out:
#                               gender age    BMI IBD
# O2.UC-11_out.list.freq_table  female  34  18.68  UC
# O2.UC-12_out.list.freq_table    male  43  21.60  UC
# O2.UC-13_out.list.freq_table  female  68  23.38  UC
# O2.UC-14_out.list.freq_table    male  31  32.65  UC
# O2.UC-16_out.list.freq_table    male  47  26.42  UC
# O2.UC-17_out.list.freq_table    male  56  21.87  UC
# O2.UC-18_out.list.freq_table    male  48  25.72  UC
# O2.UC-19_out.list.freq_table    male  42  24.15  UC
# O2.UC-1_out.list.freq_table     male  37  31.02  UC
# O2.UC-20_out.list.freq_table  female  51  24.03  UC
# O2.UC-21_out.list.freq_table  female  49  30.46  UC
# O2.UC-22_out.list.freq_table    male  44  25.39  UC
# O2.UC-23_out.list.freq_table  female  44  28.16  UC
# O2.UC-24_out.list.freq_table  female  55  28.76  UC
# O2.UC-4_out.list.freq_table   female  57  28.53  UC
# V1.CD-11_out.list.freq_table  female  62  35.46   N
# V1.CD-12_out.list.freq_table  female  41  20.20  CD
# V1.CD-13_out.list.freq_table    male  68  25.69   N
# V1.CD-14_out.list.freq_table  female  41  23.12   N
# V1.CD-15_out.list.freq_table  female  34  19.00  CD
# V1.CD-1_out.list.freq_table   female  25  17.93  CD
# V1.CD-2_out.list.freq_table     male  49  27.76   N
# V1.CD-3_out.list.freq_table   female  18  21.51   N
# V1.CD-4_out.list.freq_table   female  46  29.69   N
# V1.CD-6_out.list.freq_table   female  36  18.52  CD
# V1.CD-8_out.list.freq_table     male  51  29.38   N
# V1.CD-9_out.list.freq_table   female  48  27.55   N
# V1.UC-10_out.list.freq_table    male  45  27.31  UC
# V1.UC-13_out.list.freq_table  female  51  28.51  UC
# V1.UC-14_out.list.freq_table  female  53  20.25  UC
# V1.UC-15_out.list.freq_table  female  25  22.77  UC
# V1.UC-17_out.list.freq_table  female  41  24.46  UC
# V1.UC-18_out.list.freq_table  female  63  28.67   N
# V1.UC-19_out.list.freq_table  female  37  21.19   N
# V1.UC-21_out.list.freq_table    male  62  25.21  UC
# V1.UC-6_out.list.freq_table   female  38  23.18   N
# V1.UC-7_out.list.freq_table   female  19  23.05   N
# V1.UC-8_out.list.freq_table     male  22  25.40   N
# V1.UC-9_out.list.freq_table     male  32  30.37   N

# %%
GOS=1-GOS
figure(num=None, figsize=(12, 12))
R = dendrogram(linkage(GOS, method='average'),labels=L, leaf_font_size=13,leaf_rotation=90,orientation='right')

ylabel('points')
xlabel('Height')
#xlim(1,1.6)
suptitle('MetHit: average', fontweight='bold', fontsize=20)

# %%
from skbio.stats.distance import DistanceMatrix

# %%
dm = DistanceMatrix.from_file("../data/dm_Methit_new.txt")

# %%
 from skbio.stats.ordination import PCoA

# %%
bc_pc = PCoA(dm).scores()

# %%
bc_pc

# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
def scatter_3d(ord_results, df, column, color_map, title='', axis1=0,
...                axis2=1, axis3=2):
...    coord_matrix = ord_results.site.T
...    ids = ord_results.site_ids
...    colors = [color_map[df[column][id_]] for id_ in ord_results.site_ids]
...
...    fig = plt.figure()
...    ax = fig.add_subplot(111, projection='3d')
...
...    xs = coord_matrix[axis1]
...    ys = coord_matrix[axis2]
...    zs = coord_matrix[axis3]
...    plot = ax.scatter(xs, ys, zs, c=colors)
...
...    ax.set_xlabel('PC %d' % (axis1 + 1))
...    ax.set_ylabel('PC %d' % (axis2 + 1))
...    ax.set_zlabel('PC %d' % (axis3 + 1))
...    ax.set_xticklabels([])
...    ax.set_yticklabels([])
...    ax.set_zticklabels([])
...    ax.set_title(title)
...    return fig

# %% [markdown]
# PCoA of samples according to disease
# ========
#     - RED: 21 ulcerative colitis
#     - GREEN: 4 Crohn’s disease
#     - BLUE:  14 healthy individuals

# %%
fig = scatter_3d(bc_pc, sample_md, 'IBD', {'N': 'b', 'UC': 'r','CD': 'g'},
...                  'Samples colored by patient or not')

# %%
Image(filename="MetHit.png")

# %%
from skbio.stats.distance import ANOSIM

# %%
anosim = ANOSIM(dm, sample_md, column='IBD')

# %%
results = anosim(999)

# %%
results.statistic
# Out:
# 0.11205511941037834

# %%
results.p_value
# Out:
# 0.044999999999999998

# %% [markdown]
# - R statistic: An R value near +1 means that there is dissimilarity between the groups, while an R value near 0 indicates no significant dissimilarity between the groups. So here R=0.11 is not that promising. I am not sure if this is significant enough.
#
# - P-value = 0.045 (using ANOSIM)
#
# - Compared to 0.031 shown in Methit paper as above(the method to get this p-value may be different,I will check it), it is not bad.
#
#
#     - Their method is based on mapping reads against 155 "core" species genomes.

# %%
fig = scatter_3d(bc_pc, sample_md, 'gender', {'male': 'b', 'female': 'r'},
...                  'Samples colored by gender')

# %%
anosim = ANOSIM(dm, sample_md, column='gender')
results = anosim(999)

# %%
results.statistic
# Out:
# -0.020793234179060947

# %%
results.p_value
# Out:
# 0.61399999999999999

# %% [markdown]
# No significant difference on the gender.
