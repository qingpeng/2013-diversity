# %%
from skbio.diversity.beta import pw_distances
from skbio import DistanceMatrix
from pandas import DataFrame, read_csv,Series
from skbio.stats.distance import mantel
import matplotlib.pyplot as plt

DIR = "/Users/qingpeng/2013-diversity-Iterated/New_Test/"

dm_real = read_csv(DIR+'real_matrix.txt',sep="\t", header = 0,index_col=0)

# %%
mantel_error={}
mantel_noerror={}

for cov in [0.1, 1.0,10.0]:
    mantel_error[cov] = []
    mantel_noerror[cov] = []
    for e_v in [0,0.005,0.01,0.015,0.02,0.025,0.03]:
        
        file_string = str(cov)+'_'+str(e_v)
        print file_string
        dm_error = read_csv(DIR+'Check_Error/'+file_string+'_error/matrix.txt',sep="\t", header = 0,index_col=0)
        dm_noerror = read_csv(DIR+'Check_Error/'+file_string+'_noerror/matrix.txt',sep="\t", header = 0,index_col=0)

        mantel_error[cov].append(mantel(dm_real,dm_error,method='spearman', strict=False)[0])
        mantel_noerror[cov].append(mantel(dm_real,dm_noerror,method='spearman', strict=False)[0])
# Out:
# 0.1_0
# 0.1_0.005
# 0.1_0.01
# 0.1_0.015
# 0.1_0.02
# 0.1_0.025
# 0.1_0.03
# 1.0_0
# 1.0_0.005
# 1.0_0.01
# 1.0_0.015
# 1.0_0.02
# 1.0_0.025
# 1.0_0.03
# 10.0_0
# 10.0_0.005
# 10.0_0.01
# 10.0_0.015
# 10.0_0.02
# 10.0_0.025
# 10.0_0.03

# %%
x = [0,0.005,0.01,0.015,0.02,0.025,0.03]
x_list = [i*100 for i in x]

# %%
plt.figure(figsize=(10, 8))
plt.plot(x_list,mantel_noerror[0.1],'r*--',label = '0.1x,original')
plt.plot(x_list,mantel_noerror[1.0],'b*--',label = '1x,original')
plt.plot(x_list,mantel_noerror[10.0],'g*--',label = '10x,original')
plt.plot(x_list,mantel_error[0.1],'rs-',label = '0.1x,error_corrected')
plt.plot(x_list,mantel_error[1.0],'bs-',label = '1x,error_corrected')
plt.plot(x_list,mantel_error[10.0],'gs-',label = '10x,error_corrected')
plt.legend(loc=3)
plt.ylim(0,1.0)
plt.xlim(0,3.2)
plt.xlabel('error rate (%)')
plt.ylabel('correlation of calcuated matrix with golden standard matrix')
plt.title('beta diversity of data with different error rate')

# %%
alpha_list_error={}
alpha_list_noerror={}

for cov in [0.1, 1.0,10.0]:
    alpha_list_error[cov] = []
    alpha_list_noerror[cov] = []
    for e_v in [0,0.005,0.01,0.015,0.02,0.025,0.03]:
        
        file_string = str(cov)+'_'+str(e_v)
#        print file_string
        alpha_error = read_csv(DIR+'Check_Error/'+file_string+'_error/alpha.txt',sep=",", header = 0,index_col=0)
        alpha_noerror = read_csv(DIR+'Check_Error/'+file_string+'_noerror/alpha.txt',sep=",", header = 0,index_col=0)

        alpha_list_error[cov].append(alpha_error)
        alpha_list_noerror[cov].append(alpha_noerror)

# %%
x = [0,0.005,0.01,0.015,0.02,0.025,0.03]
x_list = [i*100 for i in x]

# %%
alpha = {}
for cov in alpha_list_error.keys():
    alpha[cov] = []
    print cov
    for df in alpha_list_error[cov]:
        alpha[cov].append(df['estimated_genome_size'])
        #print df
        #print df['estimated_genome_size']
        
print alpha

alpha_ne = {}
for cov in alpha_list_noerror.keys():
    alpha_ne[cov] = []
    print cov
    for df in alpha_list_noerror[cov]:
        alpha_ne[cov].append(df['estimated_genome_size'])
        #print df
        #print df['estimated_genome_size']
        
print alpha_ne
# Out:
# 1.0
# 10.0
# 0.1
# {1.0: [sample
# sample1    138469.841661
# sample2    199943.913676
# sample3    276131.026447
# sample4    279138.257728
# sample5    282891.470588
# sample6    270357.942857
# Name: estimated_genome_size, dtype: float64, sample
# sample1    145481.897915
# sample2    217339.750561
# sample3    306712.855951
# sample4    307836.013657
# sample5    297664.324646
# sample6    300880.459004
# Name: estimated_genome_size, dtype: float64, sample
# sample1    149154.154216
# sample2    232507.630132
# sample3    324241.376817
# sample4    328594.071852
# sample5    320616.483645
# sample6    311165.139401
# Name: estimated_genome_size, dtype: float64, sample
# sample1    160042.646734
# sample2    250315.368132
# sample3    343404.854015
# sample4    349788.749384
# sample5    353980.938691
# sample6    356814.022444
# Name: estimated_genome_size, dtype: float64, sample
# sample1    169148.484478
# sample2    263174.487650
# sample3    381244.017787
# sample4    401018.026918
# sample5    385007.223003
# sample6    368722.193878
# Name: estimated_genome_size, dtype: float64, sample
# sample1    186313.345157
# sample2    289509.656983
# sample3    419352.704082
# sample4    442686.135512
# sample5    448652.609390
# sample6    452490.292113
# Name: estimated_genome_size, dtype: float64, sample
# sample1    204518.973153
# sample2    345356.750260
# sample3    478932.430534
# sample4    491984.510109
# sample5    504253.136842
# sample6    504517.034157
# Name: estimated_genome_size, dtype: float64], 10.0: [sample
# sample1    177147
# sample2    262440
# sample3    344655
# sample4    345465
# sample5    344412
# sample6    345870
# Name: estimated_genome_size, dtype: float64, sample
# sample1    181278.000000
# sample2    269274.556657
# sample3    353585.367855
# sample4    354314.478658
# sample5    354385.287950
# sample6    354162.848069
# Name: estimated_genome_size, dtype: float64, sample
# sample1    186563.888613
# sample2    276930.751958
# sample3    364682.922441
# sample4    364612.309081
# sample5    364714.039021
# sample6    365414.476526
# Name: estimated_genome_size, dtype: float64, sample
# sample1    194033.565963
# sample2    287943.570969
# sample3    381515.311666
# sample4    380283.629374
# sample5    380617.893999
# sample6    380013.225389
# Name: estimated_genome_size, dtype: float64, sample
# sample1    206715.540984
# sample2    304440.902476
# sample3    401183.551857
# sample4    402037.748373
# sample5    400745.650244
# sample6    402574.927567
# Name: estimated_genome_size, dtype: float64, sample
# sample1    226216.654052
# sample2    330525.376838
# sample3    431095.060709
# sample4    430836.715806
# sample5    432976.656832
# sample6    434517.206584
# Name: estimated_genome_size, dtype: float64, sample
# sample1    252547.084061
# sample2    366400.310685
# sample3    474884.835422
# sample4    477304.525762
# sample5    481547.304067
# sample6    478679.589577
# Name: estimated_genome_size, dtype: float64], 0.1: [sample
# sample1    125769.600000
# sample2    182935.384615
# sample3    307800.000000
# sample4    306222.525000
# sample5    364976.470588
# sample6    252492.187500
# Name: estimated_genome_size, dtype: float64, sample
# sample1    107212.067308
# sample2    207248.275862
# sample3    366954.402332
# sample4    303079.725000
# sample5    332161.567632
# sample6    323190.000000
# Name: estimated_genome_size, dtype: float64, sample
# sample1    123655.304348
# sample2    170494.434783
# sample3    343902.981706
# sample4    482261.538462
# sample5    420565.438938
# sample6    444386.250000
# Name: estimated_genome_size, dtype: float64, sample
# sample1    138085.714286
# sample2    307800.000000
# sample3    307800.000000
# sample4    415800.000000
# sample5    363113.470588
# sample6    444386.250000
# Name: estimated_genome_size, dtype: float64, sample
# sample1    184361.062500
# sample2    306222.525000
# sample3    384841.125000
# sample4    307800.000000
# sample5    411571.800000
# sample6    363113.470588
# Name: estimated_genome_size, dtype: float64, sample
# sample1    157743.616438
# sample2    304999.848819
# sample3    454599.499316
# sample4    343800.000000
# sample5    444386.250000
# sample6    521143.875000
# Name: estimated_genome_size, dtype: float64, sample
# sample1     253800.000000
# sample2     479812.846154
# sample3     628604.550000
# sample4    1266953.400000
# sample5     446657.142857
# sample6     422762.545281
# Name: estimated_genome_size, dtype: float64]}
# 1.0
# 10.0
# 0.1
# {1.0: [sample
# sample1    159136.299597
# sample2    238053.379149
# sample3    336381.772599
# sample4    341764.181006
# sample5    344842.469413
# sample6    326412.113565
# Name: estimated_genome_size, dtype: float64, sample
# sample1    190994.284826
# sample2    293171.279330
# sample3    439737.533365
# sample4    436665.236243
# sample5    426364.080728
# sample6    427683.214286
# Name: estimated_genome_size, dtype: float64, sample
# sample1    234655.776061
# sample2    383303.022827
# sample3    555961.805085
# sample4    556208.244507
# sample5    561398.668930
# sample6    546689.396657
# Name: estimated_genome_size, dtype: float64, sample
# sample1    309365.881496
# sample2    497589.498689
# sample3    752514.282655
# sample4    756825.503226
# sample5    752538.461538
# sample6    776638.413440
# Name: estimated_genome_size, dtype: float64, sample
# sample1     412627.489227
# sample2     695386.889318
# sample3    1021175.107438
# sample4    1053618.073516
# sample5    1025729.201479
# sample6     993981.684022
# Name: estimated_genome_size, dtype: float64, sample
# sample1     578218.932628
# sample2     979566.809947
# sample3    1555455.925532
# sample4    1518875.613281
# sample5    1492602.784615
# sample6    1676688.477952
# Name: estimated_genome_size, dtype: float64, sample
# sample1     814074.095660
# sample2    1501830.539659
# sample3    2111302.077465
# sample4    2364861.761719
# sample5    2182932.391304
# sample6    2538646.534447
# Name: estimated_genome_size, dtype: float64], 10.0: [sample
# sample1    189135
# sample2    283014
# sample3    374058
# sample4    374463
# sample5    373491
# sample6    375192
# Name: estimated_genome_size, dtype: float64, sample
# sample1    239772.488671
# sample2    348618.219497
# sample3    453385.864977
# sample4    452594.593248
# sample5    453178.200108
# sample6    453907.815421
# Name: estimated_genome_size, dtype: float64, sample
# sample1    440960.368658
# sample2    530052.353632
# sample3    634160.481592
# sample4    633498.005817
# sample5    632545.297303
# sample6    629459.205127
# Name: estimated_genome_size, dtype: float64, sample
# sample1     931097.812544
# sample2     953005.449567
# sample3    1006758.773468
# sample4    1003523.519921
# sample5    1008886.372500
# sample6     997507.349258
# Name: estimated_genome_size, dtype: float64, sample
# sample1    1701427.829849
# sample2    1576004.424814
# sample3    1570928.793484
# sample4    1602030.986489
# sample5    1597952.754777
# sample6    1593101.635484
# Name: estimated_genome_size, dtype: float64, sample
# sample1    2954130.044619
# sample2    2673829.877112
# sample3    2445115.297676
# sample4    2474840.864097
# sample5    2474716.766666
# sample6    2452288.762443
# Name: estimated_genome_size, dtype: float64, sample
# sample1    4506363.823955
# sample2    4065840.105448
# sample3    3652899.606962
# sample4    3673353.542853
# sample5    3605088.352024
# sample6    3678954.148641
# Name: estimated_genome_size, dtype: float64], 0.1: [sample
# sample1    156439.459459
# sample2    239248.080000
# sample3    343800.000000
# sample4    364976.470588
# sample5    482261.538462
# sample6    264172.695652
# Name: estimated_genome_size, dtype: float64, sample
# sample1    189834.853406
# sample2    307800.000000
# sample3    631800.000000
# sample4    415800.000000
# sample5    540697.454665
# sample6    572890.909091
# Name: estimated_genome_size, dtype: float64, sample
# sample1     226842.792453
# sample2     343902.981706
# sample3     703800.000000
# sample4    1063800.000000
# sample5    1273368.600000
# sample6     909514.285714
# Name: estimated_genome_size, dtype: float64, sample
# sample1     482261.538462
# sample2    1603800.000000
# sample3     909514.285714
# sample4    1058447.250000
# sample5    2143800.000000
# sample6    1058447.250000
# Name: estimated_genome_size, dtype: float64, sample
# sample1     700245.000
# sample2    1595750.625
# sample3    1603800.000
# sample4    3223800.000
# sample5    1273368.600
# sample6    1595750.625
# Name: estimated_genome_size, dtype: float64, sample
# sample1     523800.000000
# sample2     909514.285714
# sample3    2143800.000000
# sample4    2143800.000000
# sample5    3223800.000000
# sample6    6431481.000000
# Name: estimated_genome_size, dtype: float64, sample
# sample1    3223800.00
# sample2    6463800.00
# sample3    3223800.00
# sample4    6463800.00
# sample5    3207660.75
# sample6    2133054.00
# Name: estimated_genome_size, dtype: float64]}

# %%
number = {}
color = {'sample1':'r-o','sample2':'b-o','sample3':'g-o','sample4':'g-s','sample5':'g-p','sample6':'g-*'}
for df in alpha[0.1]:
    for c in color:
        try:
            number[c].append(df[c])
        except:
            number[c] = [df[c]]
print number
plt.figure(figsize=(10, 8))
for c in color:
    plt.plot(x_list,number[c],color[c],label = c)
    
#plt.plot(x_list,alpha[0.1],'r*--',label = '0.1x,original')
plt.plot([0,3],[200000,200000],'r--')
plt.plot([0,3],[300000,300000],'b--')
plt.plot([0,3],[400000,400000],'g--')
plt.legend(loc=2)
plt.ylim(0,1000000)
plt.xlim(0,3.2)
plt.xlabel('error rate (%)')
plt.ylabel('estimated size of metagenome')
plt.title('richness estimation (0.1X, with error correction)')
# Out:
# {'sample5': [364976.47058823548, 332161.56763190962, 420565.43893766392, 363113.4705882353, 411571.8000000001, 444386.25, 446657.14285714319], 'sample4': [306222.52500000002, 303079.72499999986, 482261.5384615389, 415800.00000000029, 307800.00000000012, 343800.00000000012, 1266953.3999999999], 'sample6': [252492.1875, 323190.0, 444386.25, 444386.25, 363113.4705882353, 521143.875, 422762.54528099619], 'sample1': [125769.60000000001, 107212.06730769233, 123655.3043478261, 138085.71428571432, 184361.0625, 157743.61643835614, 253800.0], 'sample3': [307800.00000000012, 366954.40233236132, 343902.98170554201, 307800.00000000012, 384841.125, 454599.49931584136, 628604.55000000005], 'sample2': [182935.38461538465, 207248.2758620689, 170494.43478260865, 307800.00000000012, 306222.52500000002, 304999.84881895379, 479812.84615384619]}

# %%
number = {}
color = {'sample1':'r-o','sample2':'b-o','sample3':'g-o','sample4':'g-s','sample5':'g-p','sample6':'y-*'}
for df in alpha[1.0]:
    for c in color:
        try:
            number[c].append(df[c])
        except:
            number[c] = [df[c]]
print number
plt.figure(figsize=(10, 8))
for c in color:
    plt.plot(x_list,number[c],color[c],label = c)
    
#plt.plot(x_list,alpha[0.1],'r*--',label = '0.1x,original')
plt.plot([0,3],[200000,200000],'r--')
plt.plot([0,3],[300000,300000],'b--')
plt.plot([0,3],[400000,400000],'g--')
plt.legend(loc=2)
plt.ylim(0,1000000)
plt.xlim(0,3.2)
plt.xlabel('error rate (%)')
plt.ylabel('estimated size of metagenome')
plt.title('richness estimation (1X, with error correction)')
# Out:
# {'sample5': [282891.4705882353, 297664.3246463142, 320616.48364485981, 353980.93869096937, 385007.22300263389, 448652.60939012578, 504253.1368421053], 'sample4': [279138.25772825308, 307836.01365705609, 328594.07185155939, 349788.74938373052, 401018.02691790048, 442686.13551177323, 491984.51010886469], 'sample6': [270357.94285714283, 300880.45900411834, 311165.13940092165, 356814.02244389022, 368722.19387755101, 452490.29211295024, 504517.03415659477], 'sample1': [138469.8416613641, 145481.8979148271, 149154.15421570119, 160042.64673396861, 169148.484478158, 186313.34515746986, 204518.97315317465], 'sample3': [276131.0264474625, 306712.85595147841, 324241.37681728881, 343404.85401459853, 381244.01778741868, 419352.70408163272, 478932.43053435115], 'sample2': [199943.91367574254, 217339.75056107726, 232507.63013245034, 250315.36813186808, 263174.48764996469, 289509.65698324022, 345356.75025961909]}

# %%
number = {}
color = {'sample1':'r-o','sample2':'b-o','sample3':'g-o','sample4':'g-s','sample5':'g-p','sample6':'g-*'}
for df in alpha[10.0]:
    for c in color:
        try:
            number[c].append(df[c])
        except:
            number[c] = [df[c]]
print number
plt.figure(figsize=(10, 8))
for c in color:
    plt.plot(x_list,number[c],color[c],label = c)
    
#plt.plot(x_list,alpha[0.1],'r*--',label = '0.1x,original')
plt.plot([0,3],[200000,200000],'r--')
plt.plot([0,3],[300000,300000],'b--')
plt.plot([0,3],[400000,400000],'g--')
plt.legend(loc=2)
plt.ylim(0,1000000)
plt.xlim(0,3.2)
plt.xlabel('error rate (%)')
plt.ylabel('estimated size of metagenome')
plt.title('richness estimation (10X, with error correction)')
# Out:
# {'sample5': [344412.0, 354385.28794985852, 364714.03902051318, 380617.8939992814, 400745.6502437506, 432976.65683168313, 481547.30406706117], 'sample4': [345465.0, 354314.47865780408, 364612.30908050359, 380283.62937441369, 402037.74837295327, 430836.71580636711, 477304.52576179977], 'sample6': [345870.0, 354162.84806943539, 365414.47652608849, 380013.22538860107, 402574.92756697576, 434517.20658449561, 478679.58957747975], 'sample1': [177147.0, 181278.0, 186563.88861270781, 194033.56596287372, 206715.54098360657, 226216.65405172479, 252547.08406121729], 'sample3': [344655.0, 353585.36785458022, 364682.92244053772, 381515.3116659493, 401183.55185694643, 431095.06070908211, 474884.83542247437], 'sample2': [262440.0, 269274.55665722379, 276930.75195822463, 287943.57096909522, 304440.90247648297, 330525.37683819851, 366400.3106854111]}

# %%
number = {}
color = {'sample1':'r-o','sample2':'b-o','sample3':'g-o','sample4':'g-s','sample5':'g-p','sample6':'g-*'}
for df in alpha_ne[0.1]:
    for c in color:
        try:
            number[c].append(df[c])
        except:
            number[c] = [df[c]]
print number
plt.figure(figsize=(10, 8))
for c in color:
    plt.plot(x_list,number[c],color[c],label = c)
    
#plt.plot(x_list,alpha[0.1],'r*--',label = '0.1x,original')
plt.plot([0,3],[200000,200000],'r--')
plt.plot([0,3],[300000,300000],'b--')
plt.plot([0,3],[400000,400000],'g--')
plt.legend(loc=2)
plt.ylim(0,7000000)
plt.xlim(0,3.2)
plt.xlabel('error rate (%)')
plt.ylabel('estimated size of metagenome')
plt.title('richness estimation (0.1X, no error correction)')
# Out:
# {'sample5': [482261.5384615389, 540697.4546653257, 1273368.6000000001, 2143799.9999999981, 1273368.6000000001, 3223799.9999999967, 3207660.75], 'sample4': [364976.47058823548, 415800.00000000029, 1063799.9999999991, 1058447.25, 3223799.9999999967, 2143799.9999999981, 6463799.9999999935], 'sample6': [264172.69565217395, 572890.90909090859, 909514.28571428487, 1058447.25, 1595750.625, 6431481.0, 2133054.0], 'sample1': [156439.4594594595, 189834.8534057037, 226842.79245283012, 482261.5384615389, 700245.0, 523799.99999999953, 3223799.9999999967], 'sample3': [343800.00000000012, 631799.99999999942, 703799.99999999942, 909514.28571428487, 1603799.9999999988, 2143799.9999999981, 3223799.9999999967], 'sample2': [239248.0800000001, 307800.00000000012, 343902.98170554201, 1603799.9999999988, 1595750.625, 909514.28571428487, 6463799.9999999935]}

# %%
number = {}
color = {'sample1':'r-o','sample2':'b-o','sample3':'g-o','sample4':'g-s','sample5':'g-p','sample6':'g-*'}
for df in alpha_ne[1.0]:
    for c in color:
        try:
            number[c].append(df[c])
        except:
            number[c] = [df[c]]
print number
plt.figure(figsize=(10, 8))
for c in color:
    plt.plot(x_list,number[c],color[c],label = c)
    
#plt.plot(x_list,alpha[0.1],'r*--',label = '0.1x,original')
plt.plot([0,3],[200000,200000],'r--')
plt.plot([0,3],[300000,300000],'b--')
plt.plot([0,3],[400000,400000],'g--')
plt.legend(loc=2)
plt.ylim(0,7000000)
plt.xlim(0,3.2)
plt.xlabel('error rate (%)')
plt.ylabel('estimated size of metagenome')
plt.title('richness estimation (1X, no error correction)')
# Out:
# {'sample5': [344842.46941272443, 426364.08072795148, 561398.6689303905, 752538.46153846162, 1025729.2014787431, 1492602.7846153844, 2182932.3913043467], 'sample4': [341764.18100649357, 436665.23624288425, 556208.24450704223, 756825.50322580652, 1053618.0735155514, 1518875.6132812502, 2364861.7617187491], 'sample6': [326412.11356466875, 427683.21428571432, 546689.39665738156, 776638.41344046732, 993981.68402154406, 1676688.4779516363, 2538646.5344467643], 'sample1': [159136.29959668813, 190994.28482585165, 234655.7760613797, 309365.88149565051, 412627.48922687146, 578218.93262817385, 814074.09566041443], 'sample3': [336381.77259943751, 439737.53336510959, 555961.80508474598, 752514.28265524621, 1021175.1074380165, 1555455.9255319154, 2111302.0774647887], 'sample2': [238053.37914850819, 293171.27932960889, 383303.02282704116, 497589.49868904037, 695386.88931819075, 979566.80994671409, 1501830.539659359]}

# %%
number = {}
color = {'sample1':'r-o','sample2':'b-o','sample3':'g-o','sample4':'g-s','sample5':'g-p','sample6':'g-*'}
for df in alpha_ne[1.0]:
    for c in color:
        try:
            number[c].append(df[c])
        except:
            number[c] = [df[c]]
print number
plt.figure(figsize=(10, 8))
for c in color:
    plt.plot(x_list,number[c],color[c],label = c)
    
#plt.plot(x_list,alpha[0.1],'r*--',label = '0.1x,original')
plt.plot([0,3],[200000,200000],'r--')
plt.plot([0,3],[300000,300000],'b--')
plt.plot([0,3],[400000,400000],'g--')
plt.legend(loc=2)
plt.ylim(0,7000000)
plt.xlim(0,3.2)
plt.xlabel('error rate (%)')
plt.ylabel('estimated size of metagenome')
plt.title('richness estimation (10X, no error correction)')
# Out:
# {'sample5': [344842.46941272443, 426364.08072795148, 561398.6689303905, 752538.46153846162, 1025729.2014787431, 1492602.7846153844, 2182932.3913043467], 'sample4': [341764.18100649357, 436665.23624288425, 556208.24450704223, 756825.50322580652, 1053618.0735155514, 1518875.6132812502, 2364861.7617187491], 'sample6': [326412.11356466875, 427683.21428571432, 546689.39665738156, 776638.41344046732, 993981.68402154406, 1676688.4779516363, 2538646.5344467643], 'sample1': [159136.29959668813, 190994.28482585165, 234655.7760613797, 309365.88149565051, 412627.48922687146, 578218.93262817385, 814074.09566041443], 'sample3': [336381.77259943751, 439737.53336510959, 555961.80508474598, 752514.28265524621, 1021175.1074380165, 1555455.9255319154, 2111302.0774647887], 'sample2': [238053.37914850819, 293171.27932960889, 383303.02282704116, 497589.49868904037, 695386.88931819075, 979566.80994671409, 1501830.539659359]}

# %% [markdown]
# %error correction, over correction!!, fewer k-mers .... , last figure is confusing.
#
#
#
# % alpha, simulation, multiple times?????
