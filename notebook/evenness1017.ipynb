# %% [markdown]
# # Read-based coverage histograms and saturation curve

# %% [markdown]
# make -f ${PAPER}/pipeline/Makefile evenness_1017
#
# make -f ${PAPER}/pipeline/Makefile saturation_1021

# %% [markdown]
# A series of synthetic data sets were generated.
#
# * 1M genome 1X coverage
# * 1M genome 5X
# * 1M genome 10X
# * 1M genome 20X
# * 1M genome 40X
# * combine three data sets above (1X, 10X, 40X)
# * combine all 5 data sets above (1X, 5X, 10X, 20X, 40X)
#
# All With illumina error pattern

# %%
read_coverage1 = numpy.loadtxt('../data/evenness_1-Empirical.fna.gz.hist')
read_coverage10 = numpy.loadtxt('../data/evenness_10-Empirical.fna.gz.hist')
read_coverage40 = numpy.loadtxt('../data/evenness_40-Empirical.fna.gz.hist')
read_coverage1_10_40 = numpy.loadtxt('../data/evenness_1_10_40-Empirical.fna.gz.hist')
read_coverage5 = numpy.loadtxt('../data/evenness_5-Empirical.fna.gz.hist')
read_coverage20 = numpy.loadtxt('../data/evenness_20-Empirical.fna.gz.hist')
read_coverage_1_5_10_20_40 = numpy.loadtxt('../data/evenness_1_5_10_20_40-Empirical.fna.gz.hist')
read_coverage12345 = numpy.loadtxt('../data/evenness_12345-Empirical.fna.gz.hist')
read_coverage124816 = numpy.loadtxt('../data/evenness_124816-Empirical.fna.gz.hist')

saturation1 = numpy.loadtxt('../data/evenness_1-Empirical.fna.gz.C1.report')
saturation10 = numpy.loadtxt('../data/evenness_10-Empirical.fna.gz.C1.report')
saturation40 = numpy.loadtxt('../data/evenness_40-Empirical.fna.gz.C1.report')
saturation1_10_40 = numpy.loadtxt('../data/evenness_1_10_40-Empirical.fna.gz.C1.report')
saturation5 = numpy.loadtxt('../data/evenness_5-Empirical.fna.gz.C1.report')
saturation20 = numpy.loadtxt('../data/evenness_20-Empirical.fna.gz.C1.report')
saturation_1_5_10_20_40 = numpy.loadtxt('../data/evenness_1_5_10_20_40-Empirical.fna.gz.C1.report')
saturation12345 = numpy.loadtxt('../data/evenness_12345-Empirical.fna.gz.C1.report')
saturation124816 = numpy.loadtxt('../data/evenness_124816-Empirical.fna.gz.C1.report')

# %%
plot(read_coverage1[:,0], read_coverage1[:,1],'bo-')
xlabel('Estimated read coverage')
ylabel('Number of reads with that coverage')
title('1X coverage')
axis([0,50,0,60000])
# Out:
# [0, 50, 0, 60000]

# %%
plot(read_coverage10[:,0], read_coverage10[:,1],'bo-')
xlabel('Estimated read coverage')
ylabel('Number of reads with that coverage')
title('10X coverage')
axis([0,50,0,60000])
# Out:
# [0, 50, 0, 60000]

# %%
plot(saturation10[:,0], saturation10[:,1] / max(saturation10[:,0]))
axis(xmin=0, ymin=0)
title('10X coverage')
xlabel('number of reads loaded')
ylabel('fraction of non-redundant reads (coverage=1)')

# %%
plot(saturation10[:,0], saturation10[:,1])
axis(xmin=0, ymin=0,ymax=max(saturation10[:,0]))
title('10X coverage')
xlabel('number of reads loaded')
ylabel('number of non-redundant reads (coverage=1)')

# %%
plot(read_coverage40[:,0], read_coverage40[:,1],'bo-')
xlabel('Estimated read coverage')
ylabel('Number of reads with that coverage')
axis([0,50,0,60000])
title('40X coverage')

# %%
plot(saturation40[:,0], saturation40[:,1] / max(saturation40[:,0]))
axis(xmin=0, ymin=0)
title('40X coverage')
xlabel('number of reads loaded')
ylabel('fraction of non-redundant reads (coverage=1)')

# %%
plot(saturation40[:,0], saturation40[:,1])
axis(xmin=0, ymin=0,ymax=max(saturation40[:,0]))
title('40X coverage')
xlabel('number of reads loaded')
ylabel('number of non-redundant reads (coverage=1)')

# %%
plot(read_coverage1_10_40[:,0], read_coverage1_10_40[:,1],'bo-')
xlabel('Estimated read coverage')
ylabel('Number of reads with that coverage')
axis([0,50,0,60000])
title('1X,10X,40X combined')

# %%
plot(saturation1_10_40[:,0], saturation1_10_40[:,1] / max(saturation1_10_40[:,0]))
axis(xmin=0, ymin=0)
title('10X,40X combined')
xlabel('number of reads loaded')
ylabel('fraction of non-redundant reads (coverage=1)')

# %%
plot(saturation1_10_40[:,0], saturation1_10_40[:,1])
axis(xmin=0, ymin=0,ymax=max(saturation1_10_40[:,0]))
title('10X,40X combined')
xlabel('number of reads loaded')
ylabel('number of non-redundant reads (coverage=1)')

# %%
plot(read_coverage1[:,0], read_coverage1[:,1],'bo-',label='1x')
plot(read_coverage10[:,0], read_coverage10[:,1],'go-',label='10x')
plot(read_coverage40[:,0], read_coverage40[:,1],'ro-',label='40x')
plot(read_coverage1_10_40[:,0], read_coverage1_10_40[:,1],'ko-',label='all')
xlabel('Estimated read coverage')
ylabel('Number of reads with that coverage')
axis([0,50,0,60000])
legend()

# %%
plot(saturation1_10_40[:,0], saturation1_10_40[:,1] ,'k-',label='1x+10x+40x')
plot(saturation10[:,0], saturation10[:,1] ,'r-',label='10x')
plot(saturation40[:,0], saturation40[:,1] ,'c-',label='40x')

axis(xmin=0, ymin=0,ymax=max(saturation1_10_40[:,0]))
legend()

xlabel('number of reads loaded')
ylabel('number of non-redundant reads (coverage=1)')

# %%
plot(saturation1_10_40[:,0], saturation1_10_40[:,1] ,'k-',label='1x+10x+40x')
plot(saturation10[:,0], saturation10[:,1] ,'r-',label='10x')
plot(saturation40[:,0], saturation40[:,1] ,'c-',label='40x')

axis(xmin=0, ymin=0)
legend()

xlabel('number of reads loaded')
ylabel('number of non-redundant reads (coverage=1)')

# %% [markdown]
# Match perfectly. (as expected). the reads with coverage=1 may be from sequencing errors.
#
# However if there are more species, and with similar abundance, it will be difficulty to distinguish the peeks.

# %%
plot(read_coverage_1_5_10_20_40[:,0], read_coverage_1_5_10_20_40[:,1],'ko-')
plot(read_coverage1[:,0], read_coverage1[:,1],'bo-',label='1x')
plot(read_coverage5[:,0], read_coverage5[:,1],'go-',label='5x')
plot(read_coverage10[:,0], read_coverage10[:,1],'ro-',label='10x')
plot(read_coverage20[:,0], read_coverage20[:,1],'yo-',label='20x')
plot(read_coverage40[:,0], read_coverage40[:,1],'co-',label='40x')



#plot(read_coverage1_10_40[:,0], read_coverage1_10_40[:,1],'ko-',label='all')
legend()

xlabel('Estimated read coverage')
ylabel('Number of reads with that coverage')
axis([0,50,0,60000])
# Out:
# [0, 50, 0, 60000]

# %%
plot(saturation_1_5_10_20_40[:,0], saturation_1_5_10_20_40[:,1] / max(saturation_1_5_10_20_40[:,0]),'k-')
plot(saturation5[:,0], saturation5[:,1] / max(saturation5[:,0]),'g-',label='5x')
plot(saturation10[:,0], saturation10[:,1] / max(saturation10[:,0]),'r-',label='10x')
plot(saturation20[:,0], saturation20[:,1] / max(saturation20[:,0]),'y-',label='20x')
plot(saturation40[:,0], saturation40[:,1] / max(saturation40[:,0]),'c-',label='40x')

axis(xmin=0, ymin=0)
legend()

xlabel('number of reads loaded')
ylabel('fraction of non-redundant reads (coverage=1)')

# %%
plot(saturation_1_5_10_20_40[:,0], saturation_1_5_10_20_40[:,1] ,'k-')
plot(saturation5[:,0], saturation5[:,1] ,'g-',label='5x')
plot(saturation10[:,0], saturation10[:,1] ,'r-',label='10x')
plot(saturation20[:,0], saturation20[:,1] ,'y-',label='20x')
plot(saturation40[:,0], saturation40[:,1] ,'c-',label='40x')

axis(xmin=0, ymin=0,ymax=max(saturation_1_5_10_20_40[:,0]))
legend()

xlabel('number of reads loaded')
ylabel('number of non-redundant reads (coverage=1)')

# %%
plot(saturation_1_5_10_20_40[:,0], saturation_1_5_10_20_40[:,1] ,'k-')
plot(saturation5[:,0], saturation5[:,1] ,'g-',label='5x')
plot(saturation10[:,0], saturation10[:,1] ,'r-',label='10x')
plot(saturation20[:,0], saturation20[:,1] ,'y-',label='20x')
plot(saturation40[:,0], saturation40[:,1] ,'c-',label='40x')

axis(xmin=0, xmax=200000,ymin=0)
#,ymax=max(saturation_1_5_10_20_40[:,0]))
legend()

xlabel('number of reads loaded')
ylabel('number of non-redundant reads (coverage=1)')

# %% [markdown]
# Redo previous experiment.
#
# 1X, 2X, 3X, 4X, 5X
#
# and
#
# 1X, 2X, 4X, 8X, 16X
#
# Previously simulated data without error was used.
# The shape is pretty similar except the point for read coverage=1. So using median k-mer frequency can eliminate the bad effect of errors quite well.

# %%
plot(read_coverage12345[:,0], read_coverage12345[:,1],'bo-')
xlabel('Estimated read coverage')
ylabel('Number of reads with that coverage')
axis([0,15,0,60000])
title('1X, 2X, 3X, 4X, 5X combined')

# %%
plot(read_coverage124816[:,0], read_coverage124816[:,1],'bo-')
xlabel('Estimated read coverage')
ylabel('Number of reads with that coverage')
axis([0,30,0,60000])
title('1X, 2X, 4X, 8X, 16X combined')

# %%
plot(saturation12345[:,0], saturation12345[:,1] / max(saturation12345[:,0]),'go-',label='1X:2X:3X:4X:5X')
plot(saturation124816[:,0], saturation124816[:,1] / max(saturation124816[:,0]),'ro-',label='1X:2X:4X:8X:16X')

axis(xmin=0, ymin=0)
legend()

xlabel('number of reads loaded')
ylabel('fraction of non-redundant reads (coverage=1)')

# %% [markdown]
# The shape of the curve is related to the abundance distribution of underlying species. However how well we can estimate the distribution just from these curve? Is it possible theoretically? It seems that it is possible datasets with different underlying species abundance distribution can have same reads coverage distribution curve.
