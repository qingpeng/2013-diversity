# %% [markdown]
# Including:
#
# - GPGC old dataset
# - GPGC new data set
# - ARMO data set
#
#
# Conclusion:
#
# 1. All the results make sense. (using subset of 1m and 2m reads)
#
# 2. Using 2M reads dataset can get similar results using 1M reads dataset. If we just want to compare the metagenome, it may be enough to only use a small proportion of reads. It even makes more sense to use 1M/2M reads than using whole data set for old GPGC data set.
#
# 3. Other method like Commet or direct reads mapping actually is similar to thie IGS-based method using metric as Bray–Curtis (taking abundance into account). Actually Commet can give similar result as IGS based method. (see below). Our method seems faster and should have higher resolution. and is more scalable... (?) Also, an obvious advantage of IGS-based method is that we can use other metric like incidence-based metrics other than Bray-Curtis.

# %% [markdown]
# 1. GPGC old dataset:
# ====
#
#
# 1.1 1M reads subset
# ----

# %%
from IPython.display import Image
Image(filename="../figure/GPGC_old_subset1M.png")

# %% [markdown]
# 1.2 2M reads subset
# ----

# %%
Image(filename="../figure/GPGC_old_subset2M.png")

# %% [markdown]
# 2. GPGC new dataset: (soil samples from KBS)
# ====
#
# S:
#
# C:
#
# M:
#
#
# 1.1 1M reads subset
# ----

# %%
Image(filename="../figure/GPGC_new_subset1M_1.png")

# %%
Image(filename="../figure/GPGC_new_subset1M_2.png")

# %% [markdown]
# 2.2 2M reads subset
# ----

# %%
Image(filename="../figure/GPGC_new_subset2M_1.png")

# %%
Image(filename="../figure/GPGC_new_subset2M_2.png")

# %% [markdown]
# 2.3 2M reads subset (using Commet, another tool to compare metagenome based on Comparead)
# ----

# %%
Image(filename="../figure/GPGC_new_subset2M_Commet1v2.png")

# %%
Image(filename="../figure/GPGC_new_subset2M_Commet1v3.png")

# %% [markdown]
# 2. ARMO data set (1M subset)
# ====
# Amazon rainforest

# %%
Image(filename="../figure/ARMO_subset1M.png")
